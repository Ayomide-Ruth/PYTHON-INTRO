# %%
print("hello world")
print("I am learning Python!")
print("Programming is fun.")
# Out:
# hello world
# I am learning Python!
# Programming is fun.

# %%
print("I was late to class today!")
# Out:
# I was late to class today!

# %% [markdown]
# # Hello, I'm Ayo
#
# ## Hello, I'm Ayo
#
# ### Hello, I'm Ayo
#
# #### Hello, I'm Ayo
#
# i am a girl
#
# - list one
# - list two

# %%
# Step 1: Store the user's name
student_name = "Ayomide"


course_name = "Data Science and AI programming"

print("Welcome,", student_name)
print("You are enrolled in:", course_name)
print("Let us begin coding")
# Out:
# Welcome, Ayomide
# You are enrolled in: Data Science and AI programming
# Let us begin coding

# %%
student_name = "zeezay"
course_name = "Data science and AI programming"
print("Welcome,", student_name)
print("you are enrolled in:", course_name)
print("lets begin coding")
# Out:
# Welcome, zeezay
# you are enrolled in: Data science and AI programming
# lets begin coding

# %%
student_name = "Ayo"

print("My name is:", student_name)
print("With Python, I want to:")
print(" Goal 1: Be a pro in Data Science")
print(" Goal 2: Analyze data")
print(" Goal 3: Be a data scientist")
# Out:
# My name is: Ayo
# With Python, I want to:
#  Goal 1: Be a pro in Data Science
#  Goal 2: Analyze data
#  Goal 3: Be a data scientist

# %%
my_name = "zeezay"
print ("my name is:", my_name)
print ("with python, i want to:")
print(" goal 1: be a data scientist")
print(" GOAL 2: Be a health analyst")
print(" goal 3: be a foodie")
# Out:
# my name is: zeezay
# with python, i want to:
#  goal 1: be a data scientist
#  GOAL 2: Be a health analyst
#  goal 3: be a foodie

# %%
# To sum, you use sum()

# %%
# Task 1: Find the average of the scores
scores = [85, 92, 78, 95, 88]
scores_sum = sum(scores)
print("Sum of scores:", scores_sum)
average = sum(scores) / len(scores)
print("Average Score:", average)

# Task 2: Text processing
message = "python looks amazing"
print("Formatted:", message.title())

# Task 3: Decision making
file_size_mb = 150
if file_size_mb > 100:
    print("File is large. Consider compressing")
else:
    print("File size is acceptable")
# Out:
# Sum of scores: 438
# Average Score: 87.6
# Formatted: Python Looks Amazing
# File is large. Consider compressing

# %%
# Task 1: Find the average of the scores
scores= [85, 92, 78, 95, 88]
scores_sum = sum(scores)
print("sum of scores:", scores_sum)
average = sum(scores) / len(scores)
print("average score:", average)

#Task 2: Text processing
message = "python looks amazing"
print("formatted:" , message.title())

#Task 3: Decision making
file_size_mb = 150
if file_size_mb > 100:
    print("file is large. consider compressing")
else:
    print("file size is acceptable")
# Out:
# sum of scores: 438
# average score: 87.6
# formatted: Python Looks Amazing
# file is large. consider compressing

# %%
shoe_price = 75000
if shoe_price < 50000:
    print("Buy")
else:
    print("Do not buy")
# Out:
# Do not buy

# %%
shoe_price = 5000
if shoe_price < 50000:
    print("Buy")
else:
    print("Do not buy")
# Out:
# Buy

# %%
shoe_price = 90000
if shoe_price < 50000:
    print("buy")
else:
    print("do not buy")
# Out:
# do not buy

# %%
#Class Activity
# A list of python applications

python_uses = [
    "Web Development",
    "Data Science",
    "Automation",
    "Software Development",
    "Digital Marketing"
]

print("Pythin is used for:")

for use in python_uses:
    print(" -", use)

print("\nTotal domains:", len(python_uses))
# Out:
# Pythin is used for:
#  - Web Development
#  - Data Science
#  - Automation
#  - Software Development
#  - Digital Marketing
#
# Total domains: 5

# %%
python_uses = [
    "web development",
    "data science",
    "automation",
    "product design",
    "digital marketing"
]
print ("python is used for:")
for use in python_uses:
    print(" -", use)

print("\ntotal domains:", len(python_uses))
# Out:
# python is used for:
#  - web development
#  - data science
#  - automation
#  - product design
#  - digital marketing
#
# total domains: 5

# %% [markdown]
# # Week 2

# %%
# Ask the user for their name
name = input("Please enter your name:")

# Ask the user for their age
age = input("Please enter your age:")

# Display a personalized message
print("Hello,", name + "!")
print("You are", age, "years old")
print ("Welcome to Python Programming")
# Out:
# Hello, Bolu Ojo!
# You are 12 years old
# Welcome to Python Programming

# %% [markdown]
# # Class Activity
# Make a terminal form that gets user data of students, fields are:
#
# - Full name
# - Level
# - Department
# - Hobby
#
# Result Output:
# Welcome (name)! You have been enrolled to (level) in (department). We have noted you are good at (hobby)

# %%
name = input("Please enter your First and Last name:")
level = input("What level are you in?")
department = input ("What department are you enrolled in?")
hobby = input("What do you enjoy doing?")

print("Welcome,", name + "!")
print("You have been enrolled to", level, "level in", department + ".")
print("We have noted you are good at", hobby + ".")
# Out:
# Welcome, Bolu Ojo!
# You have been enrolled to 100 level in Law.
# We have noted you are good at cooking.

# %%
name = input("Please enter your First and Last name:")
level = input("What level are you in?")
department = input ("What department are you enrolled in?")
hobby = input("What do you enjoy doing?")

print("Welcome,", name + "!", "You have been enrolled to", level, "level in", department + ".", "We have noted you are good at", hobby + ".")
# Out:
# Welcome, Bolu Ojo! You have been enrolled to 100 level in Law. We have noted you are good at playing games.

# %%
name = input("Please enter your First and Last name:")
level = int(input("What level are you in?"))
department = input ("What department are you enrolled in?")
hobby = input("What do you enjoy doing?")

print("Welcome,", name + "!", "You have been enrolled to", level, "level in", department + ".", "We have noted you are good at", hobby + ".")
# Out:
# Welcome, Bolu Ojo! You have been enrolled to 100 level in Law. We have noted you are good at painting.

# %% [markdown]
# # Class Activity 2 - Set an age limit for students using the conditional statement
#
# acceptable age = (set age)
#
# # condition
# - Allow a student to enter their age
# - Write a conditional statement that checks if the age in input is less that acceptable age, print "Welcome" else print "Not ELigible"

# %%
# Acceptable age
acceptable_age = 18


student_age = int(input("How old are you?"))

if student_age < acceptable_age:
    print("Not Eligible")
else:
    print("Welcome")
# Out:
# Not Eligible

# %% [markdown]
# # INDENTATION

# %%
score = 90

if score >= 50:
    print("Result: Pass")
    print("Well done, You passed")

else:
    print("Result: Fail")
    print("Better luck next time!")
# Out:
# Result: Pass
# Well done, You passed

# %%
score = 32

if score >= 50:
    print("Result: Pass")
    print("Well done, You passed")

else:
    print("Result: Fail")
    print("Better luck next time!")
# Out:
# Result: Fail
# Better luck next time!

# %% [markdown]
# # Class Activity 2.1a - Fix the indentation

# %%
# Class activity
age = 20

if age >= 18:
print("You are an adult.")          # <-- Fix this line
    print("You can vote in elections.")  # <-- And this one

print("Age check complete.")

# %%
age = 20

if age >=18:
    print("You are an adult")
    print("You can vote in elections")
else:
    print("You are too young to vote")

print("Age check complete")
# Out:
# You are an adult
# You can vote in elections
# Age check complete

# %%
age = 17

if age >=18:
    print("You are an adult")
    print("You can vote in elections")
else:
    print("You are too young to vote.")

print("Age check complete.")
# Out:
# You are too young to vote.
# Age check complete

# %% [markdown]
# # Class Activity 2.1b
# Task: Write a program that checks if a number is positive, negative, or zero using proper indentation. Use if, elif, and else.

# %%
no. = 33

if no.

# %% [markdown]
# # Class Activity 2.2a
#
# **Task:** Add meaningful comments to the code below. Every section should have at least one comment explaining **what** the section does and **why** a particular value is used.

# %%
# CLASS ACTIVITY 2.2a — Add comments to this code

# Add your comments where indicated with <-- ADD COMMENT

product_price = 250.00       # <-- ADD COMMENT
discount_rate = 0.15         # <-- ADD COMMENT (explain why 0.15)
discount_amount = product_price * discount_rate    # <-- ADD COMMENT
final_price = product_price - discount_amount      # <-- ADD COMMENT

print("Original price:", product_price)
print("Discount:", discount_amount)
print("Final price:", final_price)

# %%
product_price = 250.00  # Current price of the product
discount_rate = 0.15    # There is a 15% discunt on the product price
discount_amount = product_price * discount_rate # This is a product of the product price and the discount rate
final_price = product_price - discount_amount # This is the difference between the product price and the discount amount.

print("Original Price:", product_price)
print("Discount:", discount_amount)
print("Final Price:", final_price)
# Out:
# Original Price: 250.0
# Discount: 37.5
# Final Price: 212.5
