# %% [markdown]
# # Mini Project — Python Identity Card¶
# Goal: Build a simple Python "Identity Card" generator.
#
# Requirements:
#
# Ask the user for: full name, age, country, favourite Python use case, and one goal for this course
# Display a formatted identity card using print() statements and =/- borders
# Include a motivational footer message

# %%
print("Hi")
# Out:
# Hi

# %%
name = input("Input your First name and Last name:")
age = int(input("How old are you?"))
country = input("What country are you from?")
use_case = input("What is your favourite python use case?")
goal = input("What is your goal?")

print("=" * 40)
print("PYTHON LEARNER IDENTITY CARD")
print("=" * 40)
print("Name:", name)
print("Age:", age)
print("Country:", country)
print("Use Case:", use_case)
print("Goal:", goal)

print("Tough times do not last. Tough people do!")
# Out:
# ...
# PYTHON LEARNER IDENTITY CARD
# ...
# Name: Bolu Ojo
# Age: 10
# Country: Nigeria
# Use Case: Data Science
# Goal: Become a Data Scientist
# Tough times do not last. Tough people do!

# %%
name = input("Input your First name and Last name:")
age = int(input("How old are you?"))
country = input("What country are you from?")
use_case = input("What is your favourite python use case?")
goal = input("What is your goal?")

print("=" * 40)
print("PYTHON LEARNER IDENTITY CARD")
print("=" * 40)
print("Name:", name)
print("Age:", age)
print("Country:", country)
print("Use Case:", use_case)
print("Goal:", goal)

print("Tough times do not last. Tough people do!")

# %% [markdown]
# # Mini Project — Smart Greeting System
# Goal: Build a Python greeting system that collects user information and generates personalised, formatted output.
#
# Requirements:
#
# - Ask the user for: name, age (as number), city, and current time of day (morning/afternoon/evening)
# - Based on the time of day, print an appropriate greeting ("Good morning", "Good afternoon", or "Good evening")
# - Calculate and display what year the user was born (hint: 2024 - age)
# - Display all information in a formatted card with borders
# - Include at least 5 meaningful comments in your code
# - Every section of code must be correctly indented

# %%
# Assign variable names to collect users information
name = input("Input your First and Last name:")
age = int(input("What year were you born"))
city = input("What city do you live in?")
time = int(input("What time of the day are you currently in? 24-hour format"))

# To creat borders, we use the code below:
print("=" * 40)

# To get what to display what time of the day it is, we use the conditional statements below:
if 0 <= time  <= 11:
    print ("Good morning!")
elif 12 <= time <= 15:
    print("Good afternoon!")
else:
    print("Good evening!")

# To create a title for the greeting system

print("=" * 40)

# To calculate the user's age based on the year the user was born, we use;
cal_age = int((2026 - age))

# To display our data, we use the print() function
print("My name is", name + ".")
print("I am", cal_age, "years old" + ".")
print("I reside in the city of", city + ".")

# To close the border
print("=" * 40)
# Out:
# ...
# Good afternoon!
# ...
# My name is Bolu Ojo.
# I am 26 years old.
# I reside in the city of Lagos.
# ...

# %% [markdown]
# ## Student Grade Calculator
# - Build a Python script that manages and reports student grades.
#
# ### Requirements
# - calculate_average(scores) — takes a list of numbers and returns the average as a float.
# - get_grade(average) — takes an average score and returns a letter grade:
# - A → 90–100
# - B → 75–89
# - C → 60–74
# - F → below 60
#
# - generate_report(name, scores) — takes a student name and a list of scores, then prints the student's name, their average, and their letter grade in a readable format.
# - Call generate_report at least twice with different students and scores to demonstrate the script works.
#
# -Deliverable
# A single file named grade_calculator.py.

# %%
# # calculate_average(scores) — takes a list of numbers and returns the average as a float.
# scores = [55, 87, 67, 54, 77]

# def calculate_average(scores):
#     #score = 0
#     total = 0

#     for score in scores:
#         total += score
#         print(total)
#         average_score = float(total / len(scores))
    
#     # print (f"Average score: {average_score}")
#         return (f"Average score: {average_score}")

# calculate_average(scores)

# %%
# Create a list of scores
scores = [55, 87, 67, 54, 77]
print (f"Scores = {scores}")

# Define a function named calculate_average
def calculate_average(scores):
    # Assign total to an empty value 0
    total = 0
    # Use for loop to create your loop and if conditional statement to create your condition
    for score in scores:
        total += score
        # print(f"Total = {total}")
    average = float(total / len(scores))
    return(average)
    #print(f"Average score for scores = {average}")

average = calculate_average(scores)
print(f"Average score of scores is {average}")
# Out:
# Scores = [55, 87, 67, 54, 77]
# Average score of scores is 68.0

# %%
# Define a function get_grade(average) that takes an average score and returns a letter grade
# where A = 90–100, B = 75–89, C = 60–74, F = below 60

#print(average) 
def get_grade(average):
    if 90 <= average <= 100:
        return("Grade A")
    elif 75 <= average <= 89:
        return("Grade B")
    elif 60 <= average <= 74:
        return("Grade C")
    else:
        return("Grade F")

grade = get_grade(average)
print(f"Your grade is {grade}")
# Out:
# Your grade is Grade C

# %%
# generate_report(name, scores)
# That takes a student name and a list of scores
# then prints the student's name, their average, and their letter grade in a readable format.

def generate_report(name, scores):
    average = calculate_average(scores)
    grade = get_grade(average)
    print(f"Student name:", name,
          "\n""Average:", average,"\n",grade)

generate_report("Bolu Ojo", [54, 90, 33, 47, 60])
print()
generate_report("Shade Kai", [65, 45, 70, 76, 88])
# Out:
# Student name: Bolu Ojo
# Average: 56.8
#  Grade F
#
# Student name: Shade Kai
# Average: 68.8
#  Grade C

# %% [markdown]
# ## Cumulative Project — Topic 10
# - Library Book Tracker
#
# - Build a library management system using functions, data structures, and all prior concepts:
#
# - add_book(library, title, author, available=True) — adds a book (as a dict) to the library list
# - search_book(library, title) — searches by title and returns the book dict or None
# - borrow_book(library, title) — marks the book as unavailable if found and available; returns a status message
# - return_book(library, title) — marks the book as available again; returns a status message
# - display_catalogue(library) — iterates and prints all books with their availability status
# - Main program: create a library with 4 books, borrow 2, return 1, then display the full catalogue

# %%
# Building a Library Book Tracker
# Enter a name for the library using the input() function
library_ = input("Enter the name of the library: ").title()


# Create an empty library list 
library_list = []

# Enter a name for the book title and author using the input() function
# title_ = input("What is the title of the book?").title()
# author_ = input("Who is the author of the book?").title()

# Print output
# print("Library name:", library_)
# print("Book Title:", title_)
# print("Author name:", author_)

# Define a function named add_book(library, title, author, available=True)
# adds a book (as a dict) to the library list
# Set available to True
available_ = True

def add_book(library, title, author, available = True):
        book = {"Library": library, "Book Title": title,"Author": author, "Available" : available_}
        library_list.append(book)
        return(library_list)

for i in range(4):
  title_ = input("What is the title of the book?").title()
  author_ = input("Who is the author of the book?").title()
  add_book(library_, title_, author_, available = True)

# add_book_ = add_book(library_, title_, author_, available = True)

print("=" * 40)
print("LIBRARY DETAILS")
print("=" * 40)
print()
print(library_list)

# Correct code
# Out:
# ...
# LIBRARY DETAILS
# ...
#
# [{'Library': 'Miva', 'Book Title': 'Good Morning Holy Spirit', 'Author': 'Benny Hinn', 'Available': True}, {'Library': 'Miva', 'Book Title': 'Gifted Hands', 'Author': 'Ben Carson', 'Available': True}, {'Library': 'Miva', 'Book Title': 'Becoming', 'Author': 'Michelle Obama', 'Available': True}, {'Library': 'Miva', 'Book Title': 'Think Big', 'Author': 'Ben Carson', 'Available': True}]

# %%
# # Mr. Ayub correction
# def add_book(library, title, author, available = True):
#    library_list = []
#    library_list.append({"Library": library, "Book Title": title,"Author": author, "Available" : available})
#    return library_list

# %%
# Mr. Ayub correction code
# from module1_topic10_project_functions import add_book



# # Enter a name for the book title and author using the input() function
# library_list = []

# # def add_book(library, title, author, available = True):
# #    library_list.append({"Library": library, "Book Title": title,"Author": author, "Available" : available})
# #    return library_list

# library = input("Enter the name of the library: ").title()

# for _ in range(2):
#     title = input("What is the title of the book?")
#     author = input("Who is the author of the book?")

        
#     library_list = add_book( library, title, author)
    

#     print('condition continues')
        
   

    

# print(library_list)

# %%
# # Building a Library Book Tracker
# # Enter a name for the library using the input() function
# library_ = input("Enter the name of the library: ").capitalize()


# # Create a library list with the library name as a dictionary
# # library_list = [{"Library": {library_},}]
# library_list = []

# # Enter a name for the book title and author using the input() function
# title_ = input("What is the title of the book?").capitalize()
# author_ = input("Who is the author of the book?").title()

# # Define a function named add_book(library, title, author, available=True)
# # adds a book (as a dict) to the library list


# def add_book(library, title, author, available = True):
#     add_book = library_list.append({"Library": library, "Book Title": title,"Author": author})
#     return (add_book)


# add_book_ = add_book(library_, title_, author_, available = True)

# # Print output
# print("Library name:", library_)
# print("Book Title:", title_)
# print("Author name:", author_)

# print("=" * 40)
# print("LIBRARY DETAILS")
# print("=" * 40)
# print()
# print("Library List",library_list)
# Out:
# Library name: Miva
# Book Title: Gifted hands
# Author name: Ben Carson
# ...
# LIBRARY DETAILS
# ...
#
# Library List [{'Library': 'Miva', 'Book Title': 'Gifted hands', 'Author': 'Ben Carson'}]

# %%
# Define a function named search_book(library, title)
# Searches by title and returns the book dict or None
# Request user to search for a book 
book_search_ = input("What book are you looking for?").title()

# Function definition
def search_book(library, title):
    for dictionary in library_list:
        if book_search_ == dictionary.get("Book Title"):
        #dictionary.get("Book Title") == book_search_:
            return(f"Found: {book_search_}")
    else:
        return(f"{book_search_}, Not found")

book_search = search_book(library_, title_)
print(book_search)

# Correct code
# Out:
# Midnight Sun, Not found

# %%
# # Define a function named borrow_book(library, title)
# # That marks the book as unavailable if found and available; returns a status message

# book_borrow_ = input("What book do you want to borrow?").title()
# available = True

# def borrow_book(library, title, available = True):
#     for dictionary in library_list:
#         if book_borrow_ == dictionary.get("Book Title"):
#             if available == True:
#                 return(book_borrow_, "is available to borrow")
#             else:
#                 return (book_borrow_, "has been borrowed")
#         else:
#             return(book_borrow_, "is not found")

# book_borrow = borrow_book(library_, book_borrow_, available = True)
# # print(library_list)
# print(book_borrow)
# Out:
# ('Purple Hibiscus', 'is not found')

# %%
# # Define a function named borrow_book(library, title)
# # That marks the book as unavailable if found and available; returns a status message

# book_borrow_ = input("What book do you want to borrow?").title()
# available = True

# def borrow_book(library, title, available = True):
#     for dictionary in library_list:
#         if book_borrow_ == dictionary.get("Book Title"):
#             if available == True:
#                 return(book_borrow_, "is available to borrow")
#             else:
#                 return (book_borrow_, "has been borrowed")
#         else:
#             return(book_borrow_, "is not found")

# book_borrow = borrow_book(library_, book_borrow_, available = True)
# # print(library_list)
# print(book_borrow)
# Out:
# ('Think Big', 'is not found')

# %%
# Define a function named borrow_book(library, title)
# That marks the book as unavailable if found and available; returns a status message

book_borrow_ = input("What book do you want to borrow?").title()
# available = True

def borrow_book(library, title):
    for dictionary in library_list:
        if book_borrow_ == dictionary.get("Book Title"):
            if dictionary.get("Available") == True:
# To update the book availablity status and mark the book as unavailable if found and available, we use
                dictionary["Available"] = False
                return(book_borrow_, "is available to borrow")
            else:
                return (book_borrow_, "has been borrowed")
    else:
        return(book_borrow_, "is not found")

book_borrow = borrow_book(library_, book_borrow_)
# print(library_list)
print(book_borrow)
# Correct code
# Out:
# ('Gifted Hands', 'is available to borrow')

# %%
# Define a function named borrow_book(library, title)
# That marks the book as unavailable if found and available; returns a status message

book_borrow_ = input("What book do you want to borrow?").title()
# available = True

def borrow_book(library, title, available = False):
    for dictionary in library_list:
        if book_borrow_ == dictionary.get("Book Title"):
            if dictionary.get("Available") == True:
# To update the borrowed book availablity status and mark the book as unavailable if found and available, we use
                dictionary["Available"] = False
                return(book_borrow_, "is available to borrow")
            else:
                return (book_borrow_, "has been borrowed")
    else:
        return(book_borrow_, "is not found")

book_borrow = borrow_book(library_, book_borrow_)
# print(library_list)
print(book_borrow)
# Out:
# ('Gifted Hands', 'has been borrowed')

# %%
# # Define a function named borrow_book(library, title)
# # That marks the book as unavailable if found and available; returns a status message

# book_borrow_ = input("What book do you want to borrow?").title()
# # available = True

# def borrow_book(library, title):
#     for dictionary in library_list:
#         if book_borrow_ == dictionary.get("Book Title") and dictionary.get("Available") == True:
#             #if available == True:
#             return(book_borrow_, "is available to borrow")
#         else:
#             return (book_borrow_, "has been borrowed")
#     else:
#         return(book_borrow_, "is not found")

# book_borrow = borrow_book(library_, book_borrow_)
# # print(library_list)
# print(book_borrow)
# Out:
# ('Purple Hibiscus', 'has been borrowed')

# %%
# Define a function named return_book(library, title) 
# marks the book as available again; returns a status message

book_return_ = input("What book are you returning?").title()

def return_book(library, title, available = True):
    for dictionary in library_list:
        if book_return_ == dictionary.get("Book Title"):
            if dictionary.get("Available") == False:
# To update the returned book availablity status and mark the book as available, we use
                dictionary["Available"] = True
                return(f"{book_return_} has been returned and is available to be borrowed.")
            else:
                if book_return_ == dictionary.get("Book Title"):
                    if dictionary.get("Available") == True:
                        return(book_return_, "was not the book borrowed")
    else:
        return (book_return_, "does not exist in the library")

book_return = return_book(library_, book_return_)
print(library_list)
print(book_return)
# Out:
# [{'Library': 'Miva', 'Book Title': 'Good Morning Holy Spirit', 'Author': 'Benny Hinn', 'Available': True}, {'Library': 'Miva', 'Book Title': 'Gifted Hands', 'Author': 'Ben Carson', 'Available': True}, {'Library': 'Miva', 'Book Title': 'Becoming', 'Author': 'Michelle Obama', 'Available': True}, {'Library': 'Miva', 'Book Title': 'Think Big', 'Author': 'Ben Carson', 'Available': True}]
# ('Under The Sea', 'does not exist in the library')

# %%
# Define a function named return_book(library, title) 
# marks the book as available again; returns a status message

book_return_ = input("What book are you returning?").title()

def return_book(library, title, available = True):
    for dictionary in library_list:
        if book_return_ == dictionary.get("Book Title"):
            if dictionary.get("Available") == False:
# To update the returned book availablity status and mark the book as available, we use
                dictionary["Available"] = True
                return(f"{book_return_} has been returned and is available to be borrowed.")
            else:
                if book_return_ == dictionary.get("Book Title"):
                    if dictionary.get("Available") == True:
                        return(book_return_, "was not the book borrowed")
    else:
        return (book_return_, "does not exist in the library")

book_return = return_book(library_, book_return_)
print(library_list)
print(book_return)
# Out:
# [{'Library': 'Miva', 'Book Title': 'Good Morning Holy Spirit', 'Author': 'Benny Hinn', 'Available': True}, {'Library': 'Miva', 'Book Title': 'Gifted Hands', 'Author': 'Ben Carson', 'Available': True}, {'Library': 'Miva', 'Book Title': 'Becoming', 'Author': 'Michelle Obama', 'Available': True}, {'Library': 'Miva', 'Book Title': 'Think Big', 'Author': 'Ben Carson', 'Available': True}]
# Gifted Hands has been returned and is available to be borrowed

# %%
# # Define a function named display_catalogue(library)
# # That iterates and prints all books with their availability status
# library_ = "Miva"
# dictionary_count = 0

# def display_catalogue(library):
#     for dictionary in library_list:
#     #for books, availability in library_list:
#         book_name = dictionary.get("Book Title")
#         book_avail = dictionary.get("Available")
#         # if dictionary_count <= 4:
#         #     dictionary_count += 1
#         #     break
#         return(f"Books: {book_name} | Availability: {book_avail}")

# library_catalogue =  display_catalogue(library_)
# print(library_catalogue)
# Out:
# Books: Good Morning Holy Spirit | Availability: True

# %%
# Define a function named display_catalogue(library)
# That iterates and prints all books with their availability status
library_ = "Miva"

def display_catalogue(library):
    for dictionary in library_list:
        book_name = dictionary.get("Book Title")
        book_avail = dictionary.get("Available")
        print(f"Books: {book_name} | Availability: {book_avail}")

display_catalogue(library_)
# library_catalogue =  display_catalogue(library_)
# print(library_catalogue)
# Out:
# Books: Good Morning Holy Spirit | Availability: True
# Books: Gifted Hands | Availability: True
# Books: Becoming | Availability: True
# Books: Think Big | Availability: True

# %%
# # Create a library with 4 books
# add_book_count = 0
# while add_book_count <= 4:
#     title_ = input("What is the title of the book?").capitalize()
#     author_ = input("Who is the author of the book?").title()
#     break
#     add_book_count += 1

# print(library_list)
# Out:
# [{'Library': 'Miva', 'Book Title': 'Purple hibiscus', 'Author': 'Chimamanda'}]

# %%
    # print({"Library": {library},
    #        "Book Title": {title},
    #        "Author": {author}
    #        })
    # return(library, title, author, available = True)
