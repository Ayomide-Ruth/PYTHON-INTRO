# %% [markdown]
# ## FOR LOOP
#
# Print the 7 times table from 1 to 12 using a for loop

# %%
numbers = range(1,13)
for number in numbers:
    multiples_of_7 = (7 * number)
    print(f"7 x {number} = {multiples_of_7}")
# Out:
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# 7 x 10 = 70
# 7 x 11 = 77
# 7 x 12 = 84

# %% [markdown]
# Print a left aligned pyramid of stars with 6 rows using a for loop

# %%
stars = range(1,7)

for star in stars:
    rows = ("*" * star)
    print (rows)
# Out:
# *
# **
# ***
# ****
# *****
# ******

# %%
# Check whether any file names appears more than once
# Print duplicate found if a duplicate exists otherwise print all files are unique

file_list = [
    "report.csv",
    "data.xlsx",
    "summary.docx",
    "report.csv",
    "data.csv"
]

# use a for loop to iterate the list
for file in file_list:
    file_count = file_list.count(file)
    #file_count = 0
    if file_count > 1:
        print(f"Duplicate found: {file}")
        break
    else:
        print(f"All files are unique")
# Out:
# Duplicate found: report.csv

# %%
# Request user input

number = int(input("Enter a random number from 1 - 100: "))
#n = number + 1
numbers = range(1,number)
print(numbers)

# if number > 100:
#         print("Enter a number between 1 and 100")
# number = int(input("Enter a random number from 1 - 100: "))

#When the right number is inputted
for number in numbers:
    if number % 2 == 0:
        continue
    print(number)

    # odd_numbers = number % 2

    divisible_by_7 = number // 7
   
    if divisible_by_7 == 1:
        print(f"{number} is divisible by 7")
        break

    # if number != 0:
    #     print(f"There are {len(number)} odd numbers before the loop stopped")
    

    if number > 100:
        print(f"{number} is out of range")
        pass   # Pass a condition that allows only numbers between 1 - 100 as inputs

else:
    print("Loop is completed. No number encountered is divisible by 7")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[70], line 6
#       2
#       3 number = int(input("Enter a random number from 1 - 100: "))
#       4 #n = number + 1
#       5 numbers = range(1,number)
# ----> 6 print(numbers.list())
#       7 # if number > 100:
#       8 #         print("Enter a number between 1 and 100")
#       9 # number = int(input("Enter a random number from 1 - 100: "))
#
# AttributeError: 'range' object has no attribute 'list'

# %%
# Request user input

number = int(input("Enter a random number from 1 - 100: "))
#n = number + 1
numbers = range(1,number)
numbers = []

# if number > 100:
#         print("Enter a number between 1 and 100")
# number = int(input("Enter a random number from 1 - 100: "))

#When the right number is inputted
for number in numbers:
    if number % 2 != 0:
        print(f"There are {len(numbers)} odd numbers before the loop stopped")
    else:
        continue
        print(number)

    odd_numbers = number % 2

    if odd_numbers != 0:
        print(f"There are {len(numbers)} odd numbers before the loop stopped")

    divisible_by_7 = number // 7
   
    if divisible_by_7 == 1:
        print(f"{number} is divisible by 7")
        break

    

    if number > 100:
        print(f"{number} is out of range")
        pass   # Pass a condition that allows only numbers between 1 - 100 as inputs

else:
    print("Loop is completed. No number encountered is divisible by 7")

# %%
#number = 14
divisible_by_7 = 2 // 7
print(divisible_by_7)
# Out:
# 0

# %%
v = []
v = range (1,40)

print(v)
# Out:
# range(1, 40)
